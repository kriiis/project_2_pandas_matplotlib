# %% [markdown]
# # Data cleaning and merging dataframes

# %% [markdown]
# ## Loading multiple datasets

# %% [markdown]
# ### Classical way
#
# Reading file by file

# %%
import pandas as pd

path = 'raw_data/'
orderlines = pd.read_csv(path + 'orderlines.csv')
orders = pd.read_csv(path + 'orders.csv')
brands = pd.read_csv(path + 'brands.csv')
products = pd.read_csv(path + 'products.csv')

# %% [markdown]
# ### Another way
#
# Using `os` and a loop to read all the files from a directory. It's also possible to read only files with a certain extension (like `.csv`):

# %%
import pandas as pd
import os
path = 'raw_data/'
path, dirs, files = next(os.walk(path))
#print(files)

# remove non-csv files
for file in files:
    if not file.endswith("csv"):
        files.remove(file)

# %%
files
# Out:
# ['brands.csv', 'orderlines.csv', 'orders.csv', 'products.csv']

# %%
# create empty list 
df_list = []

# append datasets to the list
for file in files:
    temp_df = pd.read_csv(path + file, sep=',')
    df_list.append(temp_df)

# show results
brands, orderlines, orders, products = df_list[0], df_list[1], df_list[2], df_list[3]

# %% [markdown]
# ## Data quality
#
# ### Missing values

# %%
def check_missing_values(data): 
    print('Missing values:' + '\n' + str(data.isna().sum()))

# %%
for i in range(len(df_list)): 
    print(f'File name: {files[i]}')
    check_missing_values(df_list[i])
    print('\n')
# Out:
# File name: brands.csv
# Missing values:
# short    0
# long     0
# dtype: int64
#
#
# File name: orderlines.csv
# Missing values:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64
#
#
# File name: orders.csv
# Missing values:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64
#
#
# File name: products.csv
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %% [markdown]
# ### Duplicates

# %%
def check_duplicates(data): 
    print('Duplicated rows: ', data.duplicated(keep=False).sum())

# %%
for i in range(len(df_list)): 
    print(f'File name: {files[i]}')
    check_missing_values(df_list[i])
    check_duplicates(df_list[i])
    print('\n')
# Out:
# File name: brands.csv
# Missing values:
# short    0
# long     0
# dtype: int64
# Duplicated rows:  0
#
#
# File name: orderlines.csv
# Missing values:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64
# Duplicated rows:  0
#
#
# File name: orders.csv
# Missing values:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64
# Duplicated rows:  0
#
#
# File name: products.csv
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64
# Duplicated rows:  9503

# %% [markdown]
# Based on our initial exploration we need to find a way to deal with our missing values.
#
# Do we have other problems like data inconsistency?
#
# * Example: problems with the `price` column in the `orderlines` dataframe.

# %% [markdown]
# ### Data inconsistency - wrong data types

# %%
for i in range(len(df_list)): 
    
    print(f'File name: {files[i]}')
    check_missing_values(df_list[i])
    check_duplicates(df_list[i])
    df_list[i].info()
    print('\n')
# Out:
# File name: brands.csv
# Missing values:
# short    0
# long     0
# dtype: int64
# Duplicated rows:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB
#
#
# File name: orderlines.csv
# Missing values:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64
# Duplicated rows:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB
#
#
# File name: orders.csv
# Missing values:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64
# Duplicated rows:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB
#
#
# File name: products.csv
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64
# Duplicated rows:  9503
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# Some aspects that do not make a lot of sense:
#
# * **products**:
#     * `price` and `promo_price` are loaded as objects. They should be floats.
#     * Quite a lot of missing values:
#         * `description`: 7 missing values. Maybe that could be inferred from the product name?
#         * `price`: the missing values could be filled from the `orderlines` dataset. But first we will need to clean it.
#
#
# * **orders**:
#     * `created_date` should have a date data type. Then, it would be a good quality check to see if the created date for `orders` matches with the created dates for `orderlines`.
#
#
# * **orderlines**:
#     * `unit_price` has to be a float, something wrong there.
#     * `date` has to be transformed to a date data type. Then, as we said, check that it matches with the `orders` dataset.
#
#
# * **brands**: looks fine.
#
#
# Where do we have to start? Since `orders` and `orderlines` seem very crucial to the analysis, we will start by checking that they match.

# %% [markdown]
# ## Cleaning orders

# %%
# change date datatype
orders['created_date'] = pd.to_datetime(orders['created_date'])

# %% [markdown]
# Some data I could extract from here to do a data quality check with `orderlines`:
#
# * the sum of `total_paid` on both datasets should be the same
# * the initial and last date should be the same

# %%
min(orders['created_date'])
# Out:
# Timestamp('2017-01-01 00:07:19')

# %%
max(orders['created_date'])
# Out:
# Timestamp('2018-03-14 13:58:36')

# %%
sum(orders['total_paid'])
# Out:
# nan

# %% [markdown]
# I forgot to deal with missing values on our orders dataset!

# %%
orders.shape
# Out:
# (226909, 4)

# %%
orders.isna().sum()
# Out:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64

# %%
# let's filter them out
orders.loc[orders['total_paid'].isna()]
# Out:
#         order_id        created_date  total_paid    state
# 127701    427314 2017-11-20 18:54:39         NaN  Pending
# 132013    431655 2017-11-22 12:15:24         NaN  Pending
# 147316    447411 2017-11-27 10:32:37         NaN  Pending
# 148833    448966 2017-11-27 18:54:15         NaN  Pending
# 149434    449596 2017-11-27 21:52:08         NaN  Pending

# %% [markdown]
# These orders have a state of "Pending", so I can exclude them from our dataset. We are interested in the completed ones.

# %%
orders.dropna(inplace=True)

# %% [markdown]
# Now my dataset is clean. And the total paid is:

# %%
orders.shape
# Out:
# (226904, 4)

# %%
orders['total_paid'].sum()
# Out:
# 129159615.07000001

# %% [markdown]
# ## Cleaning orderlines

# %% [markdown]
# First let's transform our date time.

# %%
orderlines['date'] = pd.to_datetime(orderlines['date'])

# %%
min(orderlines['date'])
# orders: Timestamp('2017-01-01 00:07:19')
# Out:
# Timestamp('2017-01-01 00:07:19')

# %%
max(orderlines['date'])
# orders: Timestamp('2018-03-14 13:58:36')
# Out:
# Timestamp('2018-03-14 13:58:36')

# %% [markdown]
# Yes, it seems it matches. Now let's test our total_paid.
#
# To get this value, we will have to calculate a new column, total price for each row. It would be `product_quantity` * `unit_price`. I can not multiply two different types of data. So I will have to transform the unit price to a numeric one.

# %%
orderlines['product_quantity'] * pd.to_numeric(orderlines['unit_price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.137.99"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-b7e873fbc801> in <module>
# ----> 1 orderlines['product_quantity'] * pd.to_numeric(orderlines['unit_price'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.137.99" at position 6

# %% [markdown]
# While trying to transform this column to numeric an error appears. From the error message, "Unable to parse string "1.137.99" at position 6", it seems that our dataset has some problems with the thousands separators: they were encoded as dots, and python only admits one dot per number: the _decimal_ separator!
#
# There are a lot of different ways to solve this problem. The first thing I will do is to count how many dots appear for each number using string operations. If price has more than one dot, I will consider it corrupted.

# %%
# we create a copy of the dataset
ol_temp = orderlines.copy()

# create a new column with the amount of dots in the unit_price column
ol_temp['dots'] = orderlines['unit_price'].str.count('\.')

# show the rows with more than one dot
ol_temp.query('dots > 1')
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 6       1119115    299544           0                 1  APP1582   1.137.99
# 11      1119126    299549           0                 1  PAC0929   2.565.99
# 15      1119131    299553           0                 1  APP1854   3.278.99
# 43      1119195    299582           0                 1  PAC0961   2.616.99
# 59      1119214    299596           0                 1  PAC1599   2.873.99
# ...         ...       ...         ...               ...      ...        ...
# 293862  1649999    452946           0                 1  APP2075   2.999.00
# 293887  1650045    527321           0                 1  PAC2148   3.497.00
# 293889  1650050    527324           0                 1  PAC2117   3.075.00
# 293911  1650088    527342           0                 1  APP2492   1.329.00
# 293936  1650135    527364           0                 1  APP2491   1.329.00
#
#                       date  dots
# 6      2017-01-01 01:17:21     2
# 11     2017-01-01 02:07:42     2
# 15     2017-01-01 02:14:47     2
# 43     2017-01-01 08:54:00     2
# 59     2017-01-01 09:53:11     2
# ...                    ...   ...
# 293862 2018-03-14 13:03:33     2
# 293887 2018-03-14 13:10:15     2
# 293889 2018-03-14 13:10:56     2
# 293911 2018-03-14 13:24:51     2
# 293936 2018-03-14 13:36:13     2
#
# [36169 rows x 8 columns]

# %% [markdown]
# Our theory about the thousands separators is confirmed. How can we solve this problem?
#
# My approach would be to remove all the dots for all the unit_prices, and then add a dot before the last 2 digits to all the rows. Then I will transform it into numeric values.

# %%
orderlines = orderlines.assign(unit_price_nd = orderlines['unit_price'].str.replace('\.','', regex=True))
orderlines.sample(5)
# Out:
#              id  id_order  product_id  product_quantity        sku unit_price  \
# 243471  1569440    494106           0                 1    OWC0257      18.99
# 8286    1140620    307116           0                 9    SAN0112      19.99
# 23221   1171424    319983           0                 1    QNA0150     314.99
# 24851   1174490    319721           0                 1  OWC0056-2      19.99
# 204364  1500207    464622           0                 1    POL0014     139.99
#
#                       date unit_price_nd
# 243471 2018-01-18 19:08:18          1899
# 8286   2017-01-11 10:32:21          1999
# 23221  2017-02-04 20:50:07         31499
# 24851  2017-02-08 17:16:18          1999
# 204364 2017-12-17 00:18:59         13999

# %%
orderlines['integers'] = orderlines['unit_price_nd'].str[:-2]
orderlines['digits'] = orderlines['unit_price_nd'].str[-2:]
orderlines.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                  date unit_price_nd integers digits
# 0 2017-01-01 00:07:19          1899       18     99
# 1 2017-01-01 00:19:45         39900      399     00
# 2 2017-01-01 00:20:57         47405      474     05
# 3 2017-01-01 00:51:40          6839       68     39
# 4 2017-01-01 01:06:38          2374       23     74

# %%
orderlines['new_unit_price'] = orderlines['integers'] + '.' + orderlines['digits']
orderlines.sample(5)
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 236121  1557401    489583           0                 1  APP0662     138.00
# 137709  1390210    418469           0                 1  SPH0013     119.00
# 111077  1330120    395215           0                 1  LAC0224     338.40
# 81391   1276193    369617           0                 1  SAM0086     704.99
# 213698  1518033    472951           0                 1  APP2072     965.59
#
#                       date unit_price_nd integers digits new_unit_price
# 236121 2018-01-12 13:56:29         13800      138     00         138.00
# 137709 2017-10-27 09:37:23         11900      119     00         119.00
# 111077 2017-08-31 21:30:29         33840      338     40         338.40
# 81391  2017-06-27 17:35:21         70499      704     99         704.99
# 213698 2017-12-27 09:33:54         96559      965     59         965.59

# %%
# last step is to transform it to numeric and overwrite the original column unit_price with the correct prices
orderlines['unit_price'] = pd.to_numeric(orderlines['new_unit_price'])
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  float64
#  6   date              293983 non-null  datetime64[ns]
#  7   unit_price_nd     293983 non-null  object
#  8   integers          293983 non-null  object
#  9   digits            293983 non-null  object
#  10  new_unit_price    293983 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 24.7+ MB

# %% [markdown]
# Now it is time to see if it is the same than the orders files.

# %%
#drop columns that we don't need anymore
orderlines.drop(['unit_price_nd','digits','integers','new_unit_price'], axis=1, inplace=True)

orderlines['total_price'] = orderlines['product_quantity'] * orderlines['unit_price']
sum(orderlines['total_price'])
# 129159615.07000001
# Out:
# 128776222.0298095

# %%
sum(orders['total_paid'])
# Out:
# 129159615.06991275

# %% [markdown]
# What!? After all this work the values do not match! How can we figure it out where is the problem?

# %% [markdown]
# ## Matching `orders` and `orderlines`
#
# It is possible that some orders exist in one dataset but not in the other one. This would be a potential source for this price mismatch. Let's solve it!

# %% [markdown]
# We first create a new column in the `orderlines` dataset using `assign`. We also use `isin()` to create a boolen value (True/False) that checks whether the `id_order` is present in the `orders` dataset:

# %%
(orderlines.
 assign(check_orders = orderlines.id_order.isin(orders.order_id))
)['check_orders'].sum()
# Out:
# 293743

# %%
orderlines.shape
# Out:
# (293983, 8)

# %% [markdown]
# There is a difference in the number of orders in orderlines and orders. Then, using `.query` we select rows where the value in this new column is `False`:

# %%
(orderlines.
 assign(check_orders = orderlines.id_order.isin(orders.order_id)).
 query("check_orders==False")
)
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 5       1119114    295310           0                10  WDT0249      231.79
# 63      1119218    296284           0                 1  BNQ0042      699.00
# 67      1119223    294806           0                 1  APP1849     2558.99
# 69      1119226    294806           0                 1  APP1864     2797.99
# 70      1119235    297261           0                 1  QNA0177      304.99
# ...         ...       ...         ...               ...      ...         ...
# 275665  1621177    244328           0                 1  OWC0260      349.00
# 280055  1628699    261391           0                 1  APP2352     3343.00
# 280352  1629247    287797           0                 1  SYN0182      484.11
# 280856  1630150    261391           0                 1  SAT0091       44.99
# 280869  1630178    261391           0                 1  SAT0062       49.99
#
#                       date  total_price  check_orders
# 5      2017-01-01 01:14:27      2317.90         False
# 63     2017-01-01 09:58:35       699.00         False
# 67     2017-01-01 10:09:15      2558.99         False
# 69     2017-01-01 10:15:14      2797.99         False
# 70     2017-01-01 10:17:59       304.99         False
# ...                    ...          ...           ...
# 275665 2018-02-20 13:00:45       349.00         False
# 280055 2018-02-27 11:43:25      3343.00         False
# 280352 2018-02-27 19:16:26       484.11         False
# 280856 2018-02-28 12:18:26        44.99         False
# 280869 2018-02-28 12:30:57        49.99         False
#
# [240 rows x 9 columns]

# %% [markdown]
# It looks like 240 rows in `orderlines` come from orders not present in the `orders` dataset. This is quite inconsistent, since the `orders` dataset should be the one and only source of truth for orders: if an order is not there, it should not exist. We will try to find out why that happened, but for now, let's just remove those "ghost" orders:

# %%
#only put orders in orderlines that are also in orders (check_orders == True), drop others
orderlines = (orderlines
              .assign(check_orders = orderlines.id_order.isin(orders.order_id))
              .query("check_orders==True")
             )

# %% [markdown]
# Now let's look at this problem in the opposite direction: are there orders in the `orders` dataset not present in `orderlines`?

# %%
(orders
 .assign(check_orders = orders.order_id.isin(orderlines.id_order))
 .query("check_orders==False")
)
# Out:
#         order_id        created_date  total_paid            state  \
# 8         245941 2017-01-01 10:32:23      183.52        Completed
# 65        268629 2017-01-31 11:27:25       73.23        Completed
# 75        272862 2017-04-18 18:17:10      128.99          Pending
# 82        277655 2017-02-01 08:44:55        9.99          Pending
# 83        277994 2017-01-23 18:30:11       52.99        Completed
# ...          ...                 ...         ...              ...
# 226835    527328 2018-03-14 13:14:12        0.00  Shopping Basket
# 226851    527344 2018-03-14 13:25:21        0.00      Place Order
# 226853    527346 2018-03-14 13:26:14        0.00      Place Order
# 226855    527348 2018-03-14 13:28:18        0.00      Place Order
# 226889    527382 2018-03-14 13:47:43        0.00  Shopping Basket
#
#         check_orders
# 8              False
# 65             False
# 75             False
# 82             False
# 83             False
# ...              ...
# 226835         False
# 226851         False
# 226853         False
# 226855         False
# 226889         False
#
# [22213 rows x 5 columns]

# %% [markdown]
# There are more than 22000 orders in the `orders` dataset that are not present on the `orderlines` dataset!!! We can try to find out why by looking at the state of these orders:

# %%
(orders
 .assign(check_orders = orders.order_id.isin(orderlines.id_order))
 .query("check_orders==False")
 .state.value_counts()
)
# Out:
# Place Order        12304
# Shopping Basket     9810
# Completed             45
# Cancelled             41
# Pending               13
# Name: state, dtype: int64

# %% [markdown]
# It looks like most of them are orders that were not fully completed: the products were left in the shopping basket or the order was "placed" but maybe not paid (hence the state "Place Order". Some of them were "Completed", though.
#
# This will require further research, and we might have to come back to these orders if we have to explore consumer behaviour (e.g. why are orders left in the shopping basket?), but for now, for the sake of data quality, let's drop all of these unmatched orders:

# %%
#only keep matching rows in orders
orders = (orders
          .assign(check_orders = orders.order_id.isin(orderlines.id_order))
          .query("check_orders==True")
         )

# %% [markdown]
# Let's now check again if the total paid matches:

# %%
orders.total_paid.sum()
# Out:
# 129130877.18

# %%
orderlines.total_price.sum()
# Out:
# 128659393.77

# %% [markdown]
# STILL NOT MATCHING!!! This is outrageous. Let's keep exploring.

# %% [markdown]
# ## Solving the price mismatch
#
# Let's merge both datasets and compare, order by order, the `total_price`. We will call this new merged dataset `orders_info`.
#
# *Note: To merge `orderlines` with `orders`, we have to group and aggregate `orderlines`!

# %%
orders_info = (
orderlines
    .groupby('id_order')
    .agg({'total_price':'sum'})
    .merge(orders, how='inner', left_on='id_order', right_on='order_id')
    .copy()
)
orders_info
# Out:
#         total_price  order_id        created_date  total_paid  \
# 0             44.99    241319 2017-01-02 13:35:40       44.99
# 1            129.16    241423 2017-11-06 13:10:02      136.15
# 2             10.77    242832 2017-12-31 17:40:03       15.76
# 3             77.99    243330 2017-02-16 10:59:38       84.98
# 4            153.87    243784 2017-11-24 13:35:19      157.86
# ...             ...       ...                 ...         ...
# 204686        42.99    527397 2018-03-14 13:56:38       42.99
# 204687        42.99    527398 2018-03-14 13:57:25       42.99
# 204688       141.58    527399 2018-03-14 13:57:34      141.58
# 204689        19.98    527400 2018-03-14 13:57:41       19.98
# 204690        13.99    527401 2018-03-14 13:58:36       18.98
#
#                   state  check_orders
# 0             Cancelled          True
# 1             Completed          True
# 2             Completed          True
# 3             Completed          True
# 4             Cancelled          True
# ...                 ...           ...
# 204686      Place Order          True
# 204687  Shopping Basket          True
# 204688  Shopping Basket          True
# 204689  Shopping Basket          True
# 204690      Place Order          True
#
# [204691 rows x 6 columns]

# %% [markdown]
# Now that the `total` from both datasets is in the same dataframe, we can create a new column with the difference:

# %%
orders_info= (
orders_info
    .assign(price_difference = round(orders_info['total_paid'] - orders_info['total_price'], 2)) 
)

# %%
#look only hat completed orders
(
    orders_info
        .query('state == "Completed"')
        .sort_values(by='price_difference').tail(50)
)
# Out:
#         total_price  order_id        created_date  total_paid      state  \
# 201280       147.04    523652 2018-03-09 10:40:47      167.05  Completed
# 191358        15.97    512413 2018-02-16 09:24:56       36.95  Completed
# 191719         7.98    512871 2018-02-16 12:57:43       28.96  Completed
# 191546        16.98    512656 2018-02-16 10:04:08       37.97  Completed
# 192511       210.95    513754 2018-02-18 14:50:47      231.94  Completed
# 188103        15.96    508741 2018-02-16 11:31:26       36.95  Completed
# 146           41.99    297200 2017-01-19 02:21:44       64.97  Completed
# 192487        18.98    513728 2018-02-18 14:06:44       42.97  Completed
# 101          529.99    286098 2017-01-16 14:34:55      553.98  Completed
# 191391        19.96    512456 2018-02-16 08:56:03       44.95  Completed
# 191799        20.98    512963 2018-02-16 15:42:22       46.97  Completed
# 191020        23.74    512018 2018-02-15 13:29:31       54.47  Completed
# 191929        26.28    513111 2018-02-16 22:33:34       57.55  Completed
# 192001        39.97    513190 2018-02-17 09:16:15       73.96  Completed
# 191387        15.99    512451 2018-02-16 08:51:32       52.93  Completed
# 191421         8.00    512498 2018-02-16 09:02:03       46.94  Completed
# 191859        29.98    513033 2018-02-16 18:30:02       69.97  Completed
# 191060       378.27    512066 2018-02-15 14:56:10      420.54  Completed
# 164           24.99    299189 2017-01-02 00:04:53       71.97  Completed
# 192871        43.98    514155 2018-02-19 10:36:52       94.97  Completed
# 191715        51.00    512867 2018-02-16 12:54:38      101.99  Completed
# 66            84.28    269083 2017-12-01 23:52:02      139.27  Completed
# 191576        49.98    512697 2018-02-16 10:27:35      106.97  Completed
# 191402        55.98    512469 2018-02-16 08:44:33      116.97  Completed
# 190931       278.95    511919 2018-02-15 18:22:32      339.94  Completed
# 50            69.99    264244 2018-01-29 15:33:06      141.97  Completed
# 165          155.99    299277 2017-01-12 16:05:28      231.97  Completed
# 192219        70.00    513433 2018-02-17 17:51:56      146.97  Completed
# 191687        74.60    512834 2018-02-16 12:30:49      154.18  Completed
# 191050       107.99    512051 2018-02-15 14:22:36      200.97  Completed
# 114           19.99    290383 2017-01-23 12:29:12      114.98  Completed
# 191043        33.00    512043 2018-02-15 13:57:33      136.99  Completed
# 191138        82.96    512150 2018-02-15 17:43:09      197.93  Completed
# 192933       127.00    514220 2018-02-19 12:16:20      258.98  Completed
# 9            275.75    246405 2017-11-24 10:01:27      407.96  Completed
# 191133        51.92    512145 2018-02-15 17:35:22      212.61  Completed
# 192853       158.00    514134 2018-02-19 11:29:35      320.98  Completed
# 191199        54.00    512215 2018-02-15 19:51:44      222.95  Completed
# 133           52.99    296036 2017-01-23 19:23:53      233.97  Completed
# 192100        77.64    513298 2018-02-17 12:13:00      317.51  Completed
# 191804       123.99    512969 2018-02-16 15:48:22      376.96  Completed
# 191874       249.00    513049 2018-02-16 19:03:22      504.98  Completed
# 188923      2408.99    509673 2018-02-17 16:25:44     2708.97  Completed
# 191134       313.00    512146 2018-02-15 17:32:17      632.98  Completed
# 191838        20.00    513009 2018-02-16 17:33:09      406.80  Completed
# 192231        94.98    513447 2018-02-17 19:26:59      486.89  Completed
# 188176      1291.60    508825 2018-02-16 11:21:44     2590.18  Completed
# 191738      1674.60    512894 2018-02-16 13:25:30     3356.18  Completed
# 123           66.49    293308 2017-01-01 13:33:43     2635.47  Completed
# 145           84.55    297148 2017-01-01 16:42:24     4069.54  Completed
#
#         check_orders  price_difference
# 201280          True             20.01
# 191358          True             20.98
# 191719          True             20.98
# 191546          True             20.99
# 192511          True             20.99
# 188103          True             20.99
# 146             True             22.98
# 192487          True             23.99
# 101             True             23.99
# 191391          True             24.99
# 191799          True             25.99
# 191020          True             30.73
# 191929          True             31.27
# 192001          True             33.99
# 191387          True             36.94
# 191421          True             38.94
# 191859          True             39.99
# 191060          True             42.27
# 164             True             46.98
# 192871          True             50.99
# 191715          True             50.99
# 66              True             54.99
# 191576          True             56.99
# 191402          True             60.99
# 190931          True             60.99
# 50              True             71.98
# 165             True             75.98
# 192219          True             76.97
# 191687          True             79.58
# 191050          True             92.98
# 114             True             94.99
# 191043          True            103.99
# 191138          True            114.97
# 192933          True            131.98
# 9               True            132.21
# 191133          True            160.69
# 192853          True            162.98
# 191199          True            168.95
# 133             True            180.98
# 192100          True            239.87
# 191804          True            252.97
# 191874          True            255.98
# 188923          True            299.98
# 191134          True            319.98
# 191838          True            386.80
# 192231          True            391.91
# 188176          True           1298.58
# 191738          True           1681.58
# 123             True           2568.98
# 145             True           3984.99

# %% [markdown]
# Price difference could come from shipping costs, prices paid are higher than total prices that were calculated from unit_price and product_quantity.

# %%
orders_info.price_difference.describe()
# Out:
# count    204691.000000
# mean          2.303391
# std         297.461827
# min      -36159.900000
# 25%           0.000000
# 50%           0.000000
# 75%           0.010000
# max       90898.610000
# Name: price_difference, dtype: float64

# %% [markdown]
# Looks like the maximum and minimun price differences are huge: some orders are really corrupted. But we also see from the mean and the quartiles that the price difference is neglegible for most orders.

# %% [markdown]
# ## Challenge: Remove outliers
#
# Decide on a criteria for removing orders whenever you cannot trust the price difference between `orders` and `orderlines`.

# %%
orders_info.query('price_difference >= 0 & price_difference < 105 & state == "Completed"').count() / orders_info.query('state == "Completed"').price_difference.count()
# Out:
# total_price         0.987264
# order_id            0.987264
# created_date        0.987264
# total_paid          0.987264
# state               0.987264
# check_orders        0.987264
# price_difference    0.987264
# dtype: float64

# %% [markdown]
# Shipping costs for example with gls in Spain for individuals could be something up to 100€ when shipped to the Balearics. So price differences between 0 and 100 would be ok, others would be droped. Also taking into account that the really high outliers are in state 'Sopping Basket'. And price differences between 0 and 100 already make out 98,7%

# %% [markdown]
# Save the data once you are sure you can trust it!

# %%
orderlines.to_csv(path + 'clean/orderlines_cl.csv', index=False)
orders.to_csv(path + 'clean/orders_cl.csv', index=False)

# %% [markdown]
# ## Challenge: Cleaning products

# %% [markdown]
# Now it is time to clean the products dataset. Let's do a quick review of the things where wrong:

# %%
print(products.info())
check_duplicates(products)
check_missing_values(products)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB
# None
# Duplicated rows:  9503
# Missing values:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %% [markdown]
# Looking at this overview, we can see that there are different things that has to be changed:
#
# * Data types:
#     * price should be a float
#     * promo price should be a float
# * Duplicated rows. They have to be removed.
#     * To accomplish this step you can use the method `pd.DataFrame.drop_duplicates()`. Be sure you drop all the duplicates based on the column **sku**, as it is the one you will use to merge with orderlines.
# * Missing values:
#     * Description may be can be infered by the name
#     * price. Is there a way we can extract the information from another table?
#     * type. Do we need this column for our analysis?
#
# This task can be accomoplished by using all the methods you already know.

# %% [markdown]
# ### Start of the challenge

# %%
# code here
#filter rows with missing values in column desc
sku_list = products.loc[products['desc'].isna()].sku.to_list()
sku_list
# Out:
# ['WDT0211-A',
#  'APP1622-A',
#  'PAC2334',
#  'KAN0034-A',
#  'HTE0025',
#  'OTT0200',
#  'HOW0001-A']

# %%
for s in sku_list:
    products['desc'] = products['name']

products['desc'].isna().sum()
# Out:
# 0

# %%
products.iloc[16126]
# Out:
# sku                                                    WDT0211-A
# name           Open - Purple 2TB WD 35 "PC Security Mac hard ...
# desc           Open - Purple 2TB WD 35 "PC Security Mac hard ...
# price                                                        107
# promo_price                                              814.659
# in_stock                                                       0
# type                                                        1298
# Name: 16126, dtype: object

# %%
products.loc[products['desc'].isna()]
# Out:
#              sku                                               name desc  \
# 16126  WDT0211-A  Open - Purple 2TB WD 35 "PC Security Mac hard ...  NaN
# 16128  APP1622-A  Open - Apple Smart Keyboard Pro Keyboard Folio...  NaN
# 17843    PAC2334             Synology DS718 + NAS Server | 10GB RAM  NaN
# 18152  KAN0034-A  Open - Kanex USB-C Gigabit Ethernet Adapter Ma...  NaN
# 18490    HTE0025  Hyper Pearl 1600mAh battery Mini USB Mirror an...  NaN
# 18612    OTT0200    OtterBox External Battery Power Pack 20000 mAHr  NaN
# 18690  HOW0001-A  Open - Honeywell thermostat Lyric zonificador ...  NaN
#
#            price promo_price  in_stock      type
# 16126        107     814.659         0      1298
# 16128  1.568.206   1.568.206         0      1298
# 17843     566.35   5.659.896         0  12175397
# 18152      29.99     237.925         0      1298
# 18490      24.99       22.99         1      1515
# 18612      79.99       56.99         1      1515
# 18690     199.99   1.441.174         0  11905404

# %%
prod_orderlines = products.merge(orderlines, how='inner', on = 'sku') 
prod_order_orderlines = prod_orderlines.merge(orders, how = 'left', left_on='id_order', right_on='order_id')
prod_order_orderlines.head()
# Out:
#        sku                               name  \
# 0  RAI0007  Silver Rain Design mStand Support
# 1  RAI0007  Silver Rain Design mStand Support
# 2  RAI0007  Silver Rain Design mStand Support
# 3  RAI0007  Silver Rain Design mStand Support
# 4  RAI0007  Silver Rain Design mStand Support
#
#                                            desc  price promo_price  in_stock  \
# 0  Aluminum support compatible with all MacBook  59.99     499.899         1
# 1  Aluminum support compatible with all MacBook  59.99     499.899         1
# 2  Aluminum support compatible with all MacBook  59.99     499.899         1
# 3  Aluminum support compatible with all MacBook  59.99     499.899         1
# 4  Aluminum support compatible with all MacBook  59.99     499.899         1
#
#    type       id  id_order  product_id  product_quantity unit_price  \
# 0  8696  1121326    300551           0                 1      54.99
# 1  8696  1133226    304067           0                 1      49.99
# 2  8696  1134280    304484           0                 1      49.99
# 3  8696  1136418    305406           0                 1      49.99
# 4  8696  1136825    305590           0                 1      49.99
#
#                   date  order_id        created_date  total_paid  \
# 0  2017-01-02 13:34:30  300551.0 2017-01-02 13:37:16       54.99
# 1  2017-01-07 09:02:08  304067.0 2017-01-07 09:02:08       49.99
# 2  2017-01-07 21:17:55  304484.0 2017-01-07 21:17:55       49.99
# 3  2017-01-09 07:45:12  305406.0 2017-01-09 07:43:42       79.98
# 4  2017-01-09 11:53:15  305590.0 2017-01-09 11:49:31      629.98
#
#              state
# 0        Completed
# 1  Shopping Basket
# 2  Shopping Basket
# 3  Shopping Basket
# 4  Shopping Basket

# %%
prod_order_orderlines.query('state == "Completed"').loc[prod_order_orderlines['desc'].isna()]
# Out:
#               sku                                               name desc  \
# 282554  WDT0211-A  Open - Purple 2TB WD 35 "PC Security Mac hard ...  NaN
# 282556  APP1622-A  Open - Apple Smart Keyboard Pro Keyboard Folio...  NaN
# 366699    HTE0025  Hyper Pearl 1600mAh battery Mini USB Mirror an...  NaN
# 370299  HOW0001-A  Open - Honeywell thermostat Lyric zonificador ...  NaN
#
#             price promo_price  in_stock      type       id  id_order  \
# 282554        107     814.659         0      1298  1318930    389901
# 282556  1.568.206   1.568.206         0      1298  1255529    359388
# 366699      24.99       22.99         1      1515  1543840    484351
# 370299     199.99   1.441.174         0  11905404  1577535    497327
#
#         product_id  product_quantity unit_price                 date  \
# 282554           0                 1      81.47  2017-08-16 13:23:17
# 282556           0                 1     156.82  2017-05-26 12:55:06
# 366699           0                 1      20.99  2018-01-07 16:40:59
# 370299           0                 1     144.12  2018-01-23 23:11:50
#
#         order_id        created_date  total_paid      state
# 282554  389901.0 2017-08-16 13:27:15       81.47  Completed
# 282556  359388.0 2017-05-26 12:55:55      156.82  Completed
# 366699  484351.0 2018-01-07 16:55:20       49.96  Completed
# 370299  497327.0 2018-01-23 23:41:17      151.11  Completed

# %%
products.loc[products['name'].str.contains('Open')]
# Out:
#              sku                                               name  \
# 630    BEL0127-A       Open - Belkin MIXIT Lightning iPhone Support
# 1309   SEA0043-A  Open - Seagate Barracuda 1TB 35 "SATA 7200rpm ...
# 1823   WDT0175-A  Open - Western Digital 2TB Green 35 "5400rpm h...
# 1824   WDT0181-A  Open - Western Digital Blue 1TB 25 "SATA III 5...
# 1878   NTE0056-A  Open - NewerTech NuPower Battery 65W MacBook P...
# ...          ...                                                ...
# 19254  CRU0054-A                 Open - Crucial MX500 250GB SSD 7mm
# 19256  SAN0106-A  Open - SanDisk Ultra Flair Flash Drive 64GB US...
# 19257  NKI0012-A  Open - Nokia 36mm HR Steel Smartwatch Smart Cl...
# 19258  TWS0106-A  Open - Twelve South Bridge Magic Keyboard for ...
# 19259  TPL0030-A  Open - TP-Link TL-PA4010P Passthrough Powerlin...
#
#                                                     desc   price promo_price  \
# 630    Loading dock + support synchronization with Li...   34.99     299.899
# 1309   internal hard drive for Mac and PC Refurbished...      59     442.836
# 1823              WD Internal Hard Drive 2TB Mac and PC.      90     777.933
# 1824   Reconditioned WD 1TB internal hard drive for M...      80     545.846
# 1878                 MacBook Pro 13 inch Battery 2009/14  131.99     809.662
# ...                                                  ...     ...         ...
# 19254  Hard disk SATA 250GB SSD refitted III (6 Gb / ...   86.53       66.99
# 19256  Reconditioned pendrive USB 3.0 64GB USB Flash ...   24.99     207.923
# 19257  Refurbished Nokia smart watch 36 mm Steel HR w...  189.95   1.269.864
# 19258  Light reconditioned support to hold the Keyboa...      48     260.978
# 19259  Refurbished Kit internet amplifiers with trans...  54.329     381.891
#
#        in_stock      type
# 630           0      1298
# 1309          0      1298
# 1823          0      1298
# 1824          1  12655397
# 1878          0      1298
# ...         ...       ...
# 19254         0  12215397
# 19256         0  57445397
# 19257         0  11905404
# 19258         0      8696
# 19259         0      1334
#
# [1273 rows x 7 columns]

# %%
#filter rows with missing values in column price
products.loc[products['price'].isna()]
# Out:
#              sku                                               name  \
# 34       TWS0019  Twelve South MagicWand support Apple Magic Tra...
# 1900     AII0008           Aiino Case MacBook Air 11 '' Transparent
# 2039     CEL0020  Celly Ambo Luxury Leather Case + iPhone 6 Case...
# 2042     CEL0007  Celly Wallet Case with removable cover Black i...
# 2043     CEL0012            Celly Silicone Hard Shell iPhone 6 Blue
# 2044     CEL0014        Celly Silicone Hard Shell iPhone 6 Amarillo
# 2049     CEL0015    Celly fur-lined Powerbank battery 4000mAh Black
# 2051     CEL0018     Celly Wallet Leather Case cover Black iPhone 6
# 2052     CEL0023  Celly Ambo Luxury Leather Case + Case Gold iPh...
# 2053     CEL0025  Celly Ambo Luxury Leather Case + Case iPhone 6...
# 8000     APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
# 12052    CEL0028  Celly Swing Arm button selfie with Bluetooth B...
# 12053    CEL0029  Celly extensible arm selfie with Bluetooth but...
# 12054    CEL0030  Celly Smart Drive Housing + clip car holder iP...
# 12055    CEL0031  Celly Smart Drive Case + Car clip support iPho...
# 12059    CEL0032      Celly Gost clamp fixing car + Magnetica Black
# 12060    CEL0042  Celly iPhone Case Fluor 6s / 6 Black / Transpa...
# 12061    CEL0043  Celly Fluor Case iPhone 6 / 6S Pink / Transparent
# 12062    CEL0044  Celly iPhone Case Fluor 6s / 6 Yellow / Transp...
# 12064    CEL0038           Celly Frost Cover for iPhone 6 / 6S Rosa
# 12067    CEL0033  Celly Waterproof iPad Case / Air / Pro 97 "Tra...
# 12068    CEL0034  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 12069    CEL0035  Celly Ambo cover with lid iPhone 6 / 6S Plus B...
# 12070    CEL0036  Celly Adapter Micro USB connector to Lightning...
# 12071    CEL0051   Celly 4000mAh Battery Power Bank Aluminum Dorado
# 12072    CEL0052   Celly 4000mAh Battery Power Bank Aluminum Silver
# 12073    CEL0053             Celly IceCube Case iPhone 6 / 6S Black
# 12074    CEL0054              Celly IceCube Case iPhone 6 / 6S Rosa
# 12075    CEL0055             Celly IceCube Case iPhone 6 / 6S White
# 12076    CEL0056          IceCube Celly iPhone Case 6 / 6s Amarillo
# 12077    CEL0057        Celly IceCube Case iPhone 6 / 6S Plus Black
# 12078    CEL0058         Celly IceCube Case iPhone 6 / 6S Plus Rosa
# 12079    CEL0059        Celly IceCube Case iPhone 6 / 6S Plus White
# 12080    CEL0060     Celly IceCube Case iPhone 6 / 6S Plus Amarillo
# 12088    CEL0040     Celly Frost Cover for iPhone 6 / 6S Plus White
# 12089    CEL0041              Celly iPhone 6S Plus Frost Case Black
# 12092    CEL0045         Laser Case Celly iPhone 6 / 6S Dark Silver
# 12093    CEL0046        Laser Case Celly iPhone 6 / 6S Clear Silver
# 12095    CEL0047              Laser Case Celly iPhone 6 / 6S Dorado
# 12096    CEL0048                Laser Case Celly iPhone 6 / 6S Rosa
# 12097    CEL0049         Laser Case Celly iPhone 6 / 6S Plus Dorado
# 12098    CEL0050   Laser Case Celly iPhone 6 / 6S Plus Silver Clear
# 12100    CEL0037          Celly Frost Cover for iPhone 6 / 6S Black
# 12238    CEL0027          Celly Frost Cover for iPhone 6 / 6S White
# 12242    CEL0039       Celly Frost Cover for iPhone 6 / 6S Amarillo
# 12947  CEL0034-A    (Open) Celly iPhone 6S Plus Housing Frost White
#
#                                                     desc price promo_price  \
# 34     MagicWand for wireless keyboard and Magic Trac...   NaN     299.899
# 1900       MacBook Air 11-inch casing with matte finish.   NaN       22.99
# 2039   Cover and housing together with magnet for iPh...   NaN     399.905
# 2042              Case Book for iPhone 6 card case type.   NaN     128.998
# 2043                       Hard Shell Silicone iPhone 6.   NaN        4.99
# 2044                       Hard Shell Silicone iPhone 6.   NaN      59.895
# 2049   Leather-wrapped External Battery 4000mAh for i...   NaN     239.895
# 2051   Card case with transparent protective cover fo...   NaN     294.877
# 2052   Cover and housing together with magnet for iPh...   NaN     329.894
# 2053   Cover and housing together with magnet for iPh...   NaN     449.878
# 8000   Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...   NaN     1305.59
# 12052                   selfie extendable arm for iPhone   NaN      59.895
# 12053                   selfie extendable arm for iPhone   NaN      69.902
# 12054  Magnetic holder for car Compatible iPhone 5 5s...   NaN      89.903
# 12055  Magnetic car holder compatible with iPhone 6 / 6S   NaN     149.895
# 12059     Magnetic holder for car Compatible with iPhone   NaN     119.899
# 12060                Protective Case for iPhone 6 and 6s   NaN      99.898
# 12061                Protective Case for iPhone 6 and 6s   NaN      99.898
# 12062  protective case with two colors for iPhone 6 a...   NaN      79.896
# 12064                Ultra Thin Case for iPhone 6 and 6s   NaN      89.903
# 12067  waterproof protective case for iPad bag format...   NaN     149.895
# 12068  Imiatación cover skin with removable lid for i...   NaN     199.904
# 12069  Imiatación cover skin with removable lid for i...   NaN     199.904
# 12070       Micro USB adapter cable connection Lightning   NaN      89.903
# 12071  external battery capacity 4000mAh output volta...   NaN     129.894
# 12072  external battery capacity 4000mAh output volta...   NaN     199.892
# 12073                  Anti-shock Case for iPhone 6 / 6S   NaN     169.884
# 12074                  Anti-shock Case for iPhone 6 / 6S   NaN      99.898
# 12075                  Anti-shock Case for iPhone 6 / 6S   NaN     119.899
# 12076                  Anti-shock Case for iPhone 6 / 6S   NaN     119.899
# 12077             Anti-shock Case for iPhone 6 / 6S Plus   NaN     169.896
# 12078             Anti-shock Case for iPhone 6 / 6S Plus   NaN      99.898
# 12079             Anti-shock Case for iPhone 6 / 6S Plus   NaN     119.899
# 12080             Anti-shock Case for iPhone 6 / 6S Plus   NaN     169.896
# 12088           Ultra Thin Case for iPhone 6 and 6s Plus   NaN      89.903
# 12089                Ultra Thin Case for iPhone 6 and 6s   NaN      89.903
# 12092                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12093                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12095                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12096                Protective Case for iPhone 6 and 6s   NaN     149.895
# 12097      Protective Case for iPhone 6 Plus and 6s Plus   NaN     149.895
# 12098      Protective Case for iPhone 6 Plus and 6s Plus   NaN     149.895
# 12100                Ultra Thin Case for iPhone 6 and 6s   NaN      99.898
# 12238           Flexible plastic shell for iPhone 6 / 6S   NaN      89.903
# 12242                Ultra Thin Case for iPhone 6 and 6s   NaN      89.903
# 12947           Ultra Thin Case for iPhone 6 and 6s Plus   NaN      74.893
#
#        in_stock      type
# 34            0      8696
# 1900          0  13835403
# 2039          0  11865403
# 2042          0  11865403
# 2043          0  11865403
# 2044          0  11865403
# 2049          0      1515
# 2051          0  11865403
# 2052          0  11865403
# 2053          0  11865403
# 8000          0      1282
# 12052         0  11905404
# 12053         0      5720
# 12054         0      5720
# 12055         0      5720
# 12059         0  12285400
# 12060         0  11865403
# 12061         0  11865403
# 12062         1  11865403
# 12064         0  11865403
# 12067         0  12635403
# 12068         0  11865403
# 12069         0  11865403
# 12070         1  14365395
# 12071         0      1515
# 12072         0      1515
# 12073         0  11865403
# 12074         0  11865403
# 12075         0  11865403
# 12076         0  11865403
# 12077         0      5403
# 12078         0  11865403
# 12079         0  11865403
# 12080         0  11865403
# 12088         0  11865403
# 12089         0  11865403
# 12092         0  11865403
# 12093         0  11865403
# 12095         0  11865403
# 12096         0  11865403
# 12097         0  11865403
# 12098         0  11865403
# 12100         0  11865403
# 12238         0  11865403
# 12242         0  11865403
# 12947         0      1298

# %%
products.loc[products['name'].str.contains('Celly')].count()
# Out:
# sku            43
# name           43
# desc           43
# price           0
# promo_price    43
# in_stock       43
# type           43
# dtype: int64

# %% [markdown]
# Items with missing prices are except 3 others only from company Celly (italien company selling phone cases and covers), sku starting with CEL, and Celly does not have any other products with prices so just drop the rows with missing price values

# %%
products_droped = products.dropna().copy()
products_droped.isna().sum()
# Out:
# sku            0
# name           0
# desc           0
# price          0
# promo_price    0
# in_stock       0
# type           0
# dtype: int64

# %% [markdown]
# There are also a lot of duplicated rows (9503). Take a look at the duplicates.

# %%
products_droped[products_droped.duplicated()]
# Out:
#            sku                                               name  \
# 101    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 102    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 103    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 104    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 105    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# ...        ...                                                ...
# 16831  APP2302  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 16833  APP2303  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 18190  PAR0077                         Parrot Bebop Drone 2 Power
# 18308  NKI0010              Nokia Wireless sphygmomanometer Plata
# 18514  PLA0035          Bluetooth Headset Plantronics Explorer 80
#
#                                                     desc        price  \
# 101          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 102          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 103          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 104          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 105          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# ...                                                  ...          ...
# 16831  New MacBook Pro 13-inch Core i5 Touch Bar 33 G...   26.155.941
# 16833  New MacBook Pro 13 inch Touch Bar 33 GHz Core ...  237.559.421
# 18190  Drone cuadricóptero quality camera integrated ...        699.9
# 18308     Sphygmomanometer for iPhone iPad and iPod App.       129.99
# 18514  egonómico wireless headset design for iPhone i...        39.99
#
#       promo_price  in_stock      type
# 101    11.455.917         0      1282
# 102    11.455.917         0      1282
# 103    11.455.917         0      1282
# 104    11.455.917         0      1282
# 105    11.455.917         0      1282
# ...           ...       ...       ...
# 16831  26.155.941         0  1,02E+12
# 16833  23.755.942         0  1,02E+12
# 18190   6.733.892         0  11905404
# 18308   1.149.899         1  11905404
# 18514     349.896         1      5384
#
# [8746 rows x 7 columns]

# %%
products_droped.count()
# Out:
# sku            19223
# name           19223
# desc           19223
# price          19223
# promo_price    19223
# in_stock       19223
# type           19223
# dtype: int64

# %%
products_droped.drop_duplicates(inplace=True)

# %%
products_droped.count()
# Out:
# sku            10477
# name           10477
# desc           10477
# price          10477
# promo_price    10477
# in_stock       10477
# type           10477
# dtype: int64

# %%
#investigate price column further
products_droped.sample(20)
# Out:
#              sku                                               name  \
# 10953  OLL0011-A  (Open) Olloclip 4-in-1 lens iPhone 6 / 6S and ...
# 3004     LOG0181     Ultimate Ears Wireless Speaker Roll Reef Verde
# 2439     HIC0019  Hitcase PRO + waterproof case with accessories...
# 12860    PAC1858  Synology DS216 + II | 12TB (2x6TB) Seagate Iro...
# 1788     MUV0158             Muvit Pack 3 Adapter + SIM Card Reader
# 15300    DLK0138       D-Link DAP-1365 N300 Amplifier Repeater WiFi
# 17307  SEA0098-A  Open - Seagate IronWolf 6TB NAS hard drive Sata 3
# 2216     APP0956  Apple MacBook Air 13 "i7 22 Ghz | 4GB RAM | 51...
# 16084    AP20194             Like new - Apple iPhone 6s 64GB Silver
# 15536    SXA0014  SecurityXtra NoteSaver Twin Double safety Cabl...
# 399      REP0093                              iPad 2 battery repair
# 1798     TUC0201  Pack Your Backpack Tucano MacBook Pro / Retina...
# 12807    IFX0139  iFixit Y1 Tri-wing Screwdriver Tool Apple 922-...
# 2360     IFX0013  iFixit 26 Bit Driver Kit portable repair 26 parts
# 18907    APP2378  Apple Macbook Pro 13 "Core i5 2.3GHz | 16GB | ...
# 16587    APP2074  Apple MacBook Pro 15 "Core i7 Touch Bar 28GHz ...
# 13720    BOS0049          SoundSport Bose Headphones Black Wireless
# 9269     APP1199  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 8GB ...
# 1393     APP0879     Apple iPad Air 2 Wi-Fi + Cellular 128GB Silver
# 19136    BEL0377        Belkin Thunderbolt Cable 3 40Gb / s 100W 2m
#
#                                                     desc      price  \
# 10953  gLente wide angle lens macro fisheye and macro...      79.99
# 3004   Logitech Bluetooth speaker ultra-compact porta...        129
# 2439   Case resistant to extreme conditions and wide ...     149.99
# 12860  NAS with 12TB capacity (2x6TB) IronWolf Seagat...  8.929.696
# 1788           Adjustable NanoSim and MicroSim Adapters.      12.99
# 15300  Wi-Fi amplifier with Ethernet port supports wi...      61.99
# 17307  NAS hard drive designed for systems with inter...     279.99
# 2216   laptop MacBook Air 13 inch i7 22GHz 4GB 512GB ...       1829
# 16084  Apple iPhone 6s Free Refurbished 64GB Color Si...        859
# 15536    Security cable to secure two Mac and PC devices      44.99
# 399    Repair service including parts and labor for i...      69.99
# 1798        Backpack for MacBook Pro / Retina 15 inches.       59.9
# 12807                         3-wing screwdriver for Mac       7.95
# 2360      Set 26 basic tools for iPhone iPad Mac and PC.      12.95
# 18907  New MacBook Pro 13-inch Core i5 23GHz with 16G...       2239
# 16587  New MacBook Pro 15-inch Touch Bar to 28GHz Cor...    2805.59
# 13720  In-Ear Headphone wireless waterproof and built...        179
# 9269   IMac desktop computer 27 inch 5K Retina 8GB RA...       2329
# 1393   New iPad Air 2 Wi-Fi + Cellular 128GB (MGWM2TY...  6.628.114
# 19136  2m Thunderbolt cable 3 with transmission data ...      79.99
#
#       promo_price  in_stock      type
# 10953     529.589         0      1298
# 3004      899.877         0      5398
# 2439    1.299.903         0  11865403
# 12860   7.361.785         0  12175397
# 1788       89.903         0  12585395
# 15300     289.892         0      1334
# 17307   1.722.724         0      1298
# 2216   17.739.931         0      1282
# 16084     509.001         0  24821716
# 15536      35.989         0      1325
# 399       699.899         0  1,44E+11
# 1798      529.895         0      1392
# 12807      79.896         0  14305406
# 2360      129.906         0  12645406
# 18907  21.270.046         1  1,02E+12
# 16587  25.490.042         1  1,02E+12
# 13720   1.559.896         0      5384
# 9269    2.189.005         0  5,74E+15
# 1393    6.628.114         0  42931714
# 19136     749.898         1      1325

# %%
orders_orderlines.sku.nunique()
# Out:
# 7951

# %%
products_droped.sku.nunique()
# Out:
# 10477

# %%
products_orders_lines = products.merge(orders_orderlines, how = 'inner', on = 'sku')
prices = products_orders_lines[['sku', 'name', 'price', 'promo_price','total_paid', 'product_quantity', 'unit_price','total_price']]
prices.sample(5)
#prices.query('sku == "XDO0047"')
# Out:
#             sku                                               name    price  \
# 377399  MMW0016       My MW Case MacBook Pro 13 "(Late 2016) Black    29.99
# 292550  APP2082  Apple MacBook Pro 13 "Core i5 with Touch Bar 3...  2005.59
# 318022  APP2077  Apple MacBook Pro 15 "Core i7 Touch Bar 29Ghz ...  3305.59
# 377426  MMW0016       My MW Case MacBook Pro 13 "(Late 2016) Black    29.99
# 241436  SAT0008  Satechi USB Hub Slim-C to USB-A / HDMI 4K / US...    79.99
#
#        promo_price  total_paid  product_quantity  unit_price  total_price
# 377399       20.99     7065.97                 2       22.99        45.98
# 292550  18.850.046     1869.00                 1     1869.00      1869.00
# 318022   3.074.005     3370.57                 1     3018.59      3018.59
# 377426       20.99     2591.98                 1       22.99        22.99
# 241436     499.899       59.99                 1       59.99        59.99

# %%
#first add decimals for all prices that don't have decimals (dots)
products_droped['price_new'] = products_droped.price.apply(lambda x: x if x.find('.') != -1 else x + '.00')
products_droped.sample(20)
# Out:
#              sku                                               name  \
# 18215    WDT0402                     WD 4TB MyPassport Ultra Silver
# 18337    FIT0063  High HR Fitbit activity fósica Bracelet Black ...
# 2975     GTE0053     G-Technology G-RAID 4TB USB 3.0 RAID Extraóble
# 13583    APP1716  Apple Watch Series 2 38mm Stainless Steel Case...
# 12502    OTT0131  OtterBox Gel Skin Case + Protector Clearly Alp...
# 16797    APP2254  Apple MacBook Air 13 "Core i7 22GHz | 8GB RAM ...
# 3082     APP1134        Case Apple iPhone 6 / 6s Brown Leather Case
# 12314    KIN0125          Kingston 8GB Micro SDHC Class 10 45MB / s
# 3142     OTT0122  OtterBox Defender Case for iPhone 6 / 6S Plus ...
# 10132    PAC1592  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 8GB ...
# 12163    TUC0097  Tucano Work Out 2 shoulder MacBook Pro / Air 1...
# 13690    BEA0058                    Beats On-Ear Headphones EP Blue
# 15447    PAC2179  Pack Qnap TS-453b mini 4G NAS server 8TB (4x2T...
# 18715  WDT0348-A  Open - WD My Passport 1TB External Hard Drive ...
# 1314     WDT0264  Western Digital My Passport Wireless Hard Driv...
# 15487  SEA0097-A    Open - Seagate Barracuda 1TB Hard Drive 25 "7mm
# 12984    TPL0020  TP-Link Gigabit Router D2 Archer Wi-Fi ac 750 ...
# 14568    SAT0023         Satechi Support iPhone Aluminum Gray Space
# 1118     NTE0066        NewerTech Lightning to USB Cable 50cm Black
# 11210    PAC1651   Pack QNAP TS-253A | 4G RAM | 6TB Seagate Desktop
#
#                                                     desc       price  \
# 18215  4TB External Hard Drive USB 3.0 with Mac and P...      199.99
# 18337  Bracelet High HR multisport activity Fitbit la...      149.95
# 2975   extraóble disk RAID FireWire 800 and USB 3.0 f...      408.99
# 13583  Apple Watch 38 mm with GPS dual-core processor...        1219
# 12502  Screen protector anti-scratch + transparent ge...       34.99
# 16797  laptop MacBook Air 13 inch i7 22GHz 8GB RAM an...        1779
# 3082   ultrathin leather case and microfiber premium ...          55
# 12314                   8GB micro SDHC card with adapter        4.99
# 3142   Funda iPhone 6 / 6S ultra resistant multilayer...       59.99
# 10132  Desktop computer iMac 27-inch 3.2GHz Core i5 5...        3169
# 12163     Ergonomic shoulder lightly with multibolsillos       49.99
# 13690  Headphones type hull rigid shell and RemoteTal...       99.95
# 15447  NAS with HDMI 4K (3840x2160) output 4-core pro...      959.05
# 18715  External Hard Drive USB 3.0 1TB refurbished wi...       89.99
# 1314         WD External Hard Drive Wireless Mac and PC.      209.99
# 15487  Internal Hard Drive 1TB 7mm and 25 for Mac and PC       69.99
# 12984  Dual band Gigabit Router with 750Mbps wifi ac ...      84.579
# 14568  Stand with aluminum finish Lightning access to...       34.99
# 1118   Lightning 50cm USB cable to charge and sync iP...       21.99
# 11210  QNAP Pack + 16GB RAM memory + 12TB (2x6TB) Sea...  10.880.582
#
#       promo_price  in_stock      type   price_new price_num price_dec
# 18215   1.647.947         0  11935397      199.99       199        99
# 18337   1.249.906         1  11905404      149.95       149        95
# 2975    3.199.942         0  12995397      408.99       408        99
# 13583        1219         0  24885185     1219.00      1219        00
# 12502       22.99         1  13555403       34.99        34        99
# 16797  16.900.046         0  2,17E+11     1779.00      1779        00
# 3082      509.894         0  11865403       55.00        55        00
# 12314       4.281         0  57445397        4.99         4        99
# 3142      299.899         1  11865403       59.99        59        99
# 10132  25.979.898         0  5,74E+15     3169.00      3169        00
# 12163      38.691         0     10230       49.99        49        99
# 13690     899.901         0      5384       99.95        99        95
# 15447   7.783.676         0  12175397      959.05       959        05
# 18715     549.999         0  11935397       89.99        89        99
# 1314    1.999.888         0  11935397      209.99       209        99
# 15487     490.765         0      1298       69.99        69        99
# 12984     439.896         0      1334      84.579        84       579
# 14568     249.901         1      5720       34.99        34        99
# 1118      119.899         1      1230       21.99        21        99
# 11210  10.011.794         1  12175397  10.880.582    10.880       582

# %%
#second rsplit decimals (last 1, 2 or 3 numbers separated by a dot)
products_droped[['price_num', 'price_dec']]=products_droped.price_new.str.rsplit(pat='.', n=1, expand=True)

# %%
products_droped.sample(20)
# Out:
#              sku                                               name  \
# 15879    ALL0014  Allocacoc PowerCube Extended USB plug strip Wh...
# 1800     GRT0362  Griffin Survivor All-Terrain resistant Case iP...
# 15315    GLY0008         Glyph Atom 525GB SSD Hard Drive USB-C Gray
# 2884     APP1104                  Apple iPod Shuffle 2GB Gray Space
# 15685    HOC0008  Nike hoco Series Apple Watch Strap 42mm Black ...
# 1911   LGE0009-A  Open - 34UM95 LG LCD Monitor 34 "Ultra WQHD re...
# 11662    JMO0092  Just Mobile iPhone Charger Stand Silver HoverDock
# 11665  SAM0067-A              Open - Samsung 850 EVO SSD Disk 250GB
# 1348     PUR0131  Puro Booklet Slim founded with support iPad Ai...
# 17145    AP20222     Like new - Apple iPad mini 2 Wi-Fi 32GB Silver
# 15542    SXA0015      SecurityXtra Prolock Security Support Mac Pro
# 2870     APP1098                          Apple iPod Nano 16Gb Gold
# 12599    OTT0132  OtterBox Symmetry Alpha Glass Case + Screen Pr...
# 11579    PAC1287        QNAP TS-451 Pack | 4GB RAM | WD 8TB Network
# 16258    APP2231  Apple iMac 27 "Core i7 Retina 5K 42GHz | 8GB |...
# 16981    BNQ0056  PD3200U Monitor Benq 32 "4K UHD professional d...
# 16846    GLY0011  Glyph Atom SSD SSD RAID 2TB USB-C (3.1Gen2) Si...
# 1932     PAC0678  Samsung SSD 850 expansion kit EVO 250GB + 16GB...
# 15385    REP0384                   Cases mini repair front camera 3
# 14519    STA0032     Startech Gigabit Ethernet Cable Cat. 6 2m Gray
#
#                                                     desc      price  \
# 15879  Outlet power strip extension 15m cube-shaped w...      24.95
# 1800                resistant to ultra Air 2 cases. Case      79.99
# 15315  External Hard Drive 525GB SSD with USB-C conne...     304.99
# 2884       Music player iPod Shuffle 2GB and small size.         55
# 15685             Silicone Strap Sports Watch 42mm Apple         45
# 1911   Monitor ultrapanorámico IPS 21: 9 34-inch Thun...        919
# 11662  Smart charging stand for iPhone with Lightning...      39.95
# 11665  SSD hard drive Mac and PC 25 inch 250GB SATA I...     107.99
# 1348               Smart Case with Stand for iPad Air 2.      44.95
# 17145           Refurbished iPad Mini 2 32GB Wi-Fi Plata        289
# 15542    Safety housing with mounting system for Mac Pro     179.99
# 2870   Music player iPod Nano 16GB the 8th generation...        179
# 12599  Pack OtterBox Symmetry Case + Screen Protector...      49.99
# 11579  Pack QNAP TS-451 + 8TB (4x2TB) Network WD Hard...        979
# 16258  IMac desktop computer 27 inch 5K Retina 8GB RA...       3079
# 16981  32 inch monitor with 100% sRGB 4K height adjus...        773
# 16846  2TB SSD with USB-C connection (compatible Thun...    1033.99
# 1932   250GB SSD expansion kit + RAM + 16GB 1333MHz D...     415.96
# 15385  Repair service including parts and labor for i...  6.999.003
# 14519    Ethernet Cable 2 meters Mac and PC Unit Class 6       4.99
#
#       promo_price  in_stock      type  price_new price_num price_dec
# 15879     189.897         1      5395      24.95        24        95
# 1800      599.918         0  12635403      79.99        79        99
# 15315   2.399.914         0  11935397     304.99       304        99
# 2884      588.108         0  11821715      55.00        55        00
# 15685     249.889         0      2449      45.00        45        00
# 1911    6.729.081         0      1298     919.00       919        00
# 11662     328.999         0  13615399      39.95        39        95
# 11665     855.845         0      1298     107.99       107        99
# 1348      299.959         0  12635403      44.95        44        95
# 17145   2.328.113         0  12031714     289.00       289        00
# 15542   1.799.899         0      8696     179.99       179        99
# 2870    1.828.116         0  11821715     179.00       179        00
# 12599     119.899         0  11865403      49.99        49        99
# 11579      822.99         0  12175397     979.00       979        00
# 16258  29.250.044         0  5,74E+15    3079.00      3079        00
# 16981   7.729.988         0      1296     773.00       773        00
# 16846   8.399.941         0  11935397    1033.99      1033        99
# 1932    3.415.842         1      1433     415.96       415        96
# 15385       69.99         0  1,44E+11  6.999.003     6.999       003
# 14519      39.906         1      1325       4.99         4        99

# %%
products_prices = products_droped.merge(orderlines, on='sku', how='left')
products_prices.sample(5)
# Out:
#             sku                                               name  \
# 99728   APP1216                             Apple Magic Trackpad 2
# 233427  APP2085  Apple MacBook Pro 13 "Core i5 with Touch Bar 3...
# 99541   APP1216                             Apple Magic Trackpad 2
# 89040   APP1190                   IPhone AppleCare Protection Plan
# 175756  WDT0348                  WD Blue 500GB SATA 3 SSD Disk 7mm
#
#                                                      desc    price  \
# 99728                  Apple Wireless Bluetooth Trackpad.      149
# 233427  New MacBook Pro 13 inch Touch Bar 31 GHz Core ...  2255.59
# 99541                  Apple Wireless Bluetooth Trackpad.      149
# 89040                Apple Care extended warranty iPhone.       70
# 175756  SSD 500GB SATA Hard Disk 3.0 (6Gb / s) for Mac...      169
#
#        promo_price  in_stock      type price_new price_num price_dec  \
# 99728          139         1      1387    149.00       149        00
# 233427  20.980.045         0  1,02E+12   2255.59      2255        59
# 99541          139         1      1387    149.00       149        00
# 89040      609.997         1      1231     70.00        70        00
# 175756     149.994         0  12215397    169.00       169        00
#
#                id  id_order  product_id  product_quantity unit_price  \
# 99728   1589537.0  501842.0         0.0               1.0     130.00
# 233427  1643801.0  524615.0         0.0               1.0   2.098.00
# 99541   1587120.0  501003.0         0.0               1.0     130.00
# 89040   1543574.0  484281.0         0.0               1.0      54.00
# 175756  1486555.0  458913.0         0.0               1.0     159.00
#
#                        date
# 99728   2018-01-30 11:02:11
# 233427  2018-03-10 08:42:26
# 99541   2018-01-29 13:10:50
# 89040   2018-01-07 14:23:35
# 175756  2017-12-10 12:38:24

# %%
three_decimals = products_droped.loc[products_droped['price_dec'].str.len()==3]
two_decimals = products_droped.loc[products_droped['price_dec'].str.len()==2]
one_decimal = products_droped.loc[products_droped['price_dec'].str.len()==1]
price_ok = products_droped.loc[products_droped['price_dec'].str.len()<=2]

# %%
price_ok.price.str.count('\.')
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 19321    1
# 19322    1
# 19323    1
# 19324    1
# 19325    1
# Name: price, Length: 9940, dtype: int64

# %%
three_decimals.sku.count()
# Out:
# 537

# %%
three_decimals.sample(20)
# Out:
#              sku                                               name  \
# 18939  SAM0114-A  Open - Samsung LS22F352FHU Monitor 22 "FHD HDM...
# 2683     QNA0110              TVS-663-4G QNAP NAS server Mac and PC
# 15329    REP0273  volume button repair on vibration control and ...
# 15902    PAC2006  Synology DS1517 + | 8GB RAM | 40TB (5x8TB) Sea...
# 15476    REP0335                      Repair iPad 3 Headphone Input
# 13201    PAC1515  Pack QNAP TS-251A NAS Server | 8GB RAM | WD 16...
# 2399     DEV0011                        Devolo Wifi Repeater 24 GHz
# 12128    UAG0037     Urban Armor Gear Case iPad Pro 97 "Red / Black
# 12872    PAC2029  Synology DS216 + II | Seagate 4TB IronWolf for...
# 12983    TPL0016  TP-Link Gigabit Router Archer C5 Wi-Fi ac 1200...
# 526      SEV0025          Service installation RAM + HDD + SSD iMac
# 18526    WDT0400                       WD My Cloud Home 3TB USB 3.0
# 13322    APP1751  Apple iPad Air 2 Wi-Fi + Cellular 32GB Space Gray
# 1058     MOP0058  Mophie Space Pack Battery Case (1700mAh) and S...
# 12882    PAC2039  Synology DS216 + II | Seagate 4TB IronWolf for...
# 15394    REP0344                   posterior chamber repair cases 4
# 14945  WAC0136-A                Open - Wacom Intuos Pen Replacement
# 15913    PAC2017  Synology DS1517 + | 16GB RAM | 30TB (5x6TB) Se...
# 11204    PAC1648       QNAP TS-253A | 16GB RAM | 4TB (2x2TB) WD Red
# 14988  SAN0131-A     Open - SanDisk 120GB SSD Plus 25 "SATA 6Gb / s
#
#                                                     desc       price  \
# 18939  Monitor 22-inch Full HD VGA HDMI connection. 7...     109.989
# 2683                   NAS server 6 bays for Mac and PC.   9.669.897
# 15329  Repair service including parts and labor for i...   6.999.003
# 15902           NAS with 8GB RAM and 40TB for Mac and PC  27.187.885
# 15476  Repair service including parts and labor for i...   6.999.003
# 13201  NAS with 8GB RAM and two hard disks 8TB (2x8TB...  11.956.689
# 2399                    Amplifier Wi-Fi N 24 GHz Devolo.     399.905
# 12128                 Super durable Case for iPad Pro 97     499.899
# 12872  Synology DS216 + II with 2GB of RAM and 12TB (...   9.339.496
# 12983  Dual Band Wireless Gigabit Router AC1200 iPhon...     108.779
# 526    installation RAM HDD + SSD + on your iMac + Da...     599.918
# 18526                    1-bay NAS server for Mac and PC   2.049.946
# 13322  New iPad Air 2 Wi-Fi + Cellular 32GB (MNVP2TY ...   5.528.115
# 1058   Housing with battery and 32GB external storage...   1.599.862
# 12882  Synology DS216 + II with 8GB of RAM and 6TB (2...   7.879.496
# 15394  Repair service including parts and labor for i...   6.999.003
# 14945                    Pointer parts for Wacom tablets     349.932
# 15913       NAS with 16GB of RAM and 30TB for Mac and PC  23.847.892
# 11204  16GB NAS + 4TB of RAM memory (2x2TB) Seagate H...   7.480.582
# 14988                                SSD 120GB 25 inches   6.352.863
#
#       promo_price  in_stock      type   price_new price_num price_dec
# 18939   1.069.895         0      1296     109.989       109       989
# 2683    9.669.897         0  12175397   9.669.897     9.669       897
# 15329       69.99         0  1,44E+11   6.999.003     6.999       003
# 15902  20.069.629         0  12175397  27.187.885    27.187       885
# 15476       69.99         0  1,44E+11   6.999.003     6.999       003
# 13201   9.679.903         0  12175397  11.956.689    11.956       689
# 2399      329.846         1      1334     399.905       399       905
# 12128     499.899         0  12635403     499.899       499       899
# 12872     771.179         0  12175397   9.339.496     9.339       496
# 12983     999.896         0      1334     108.779       108       779
# 526       599.918         0  20642062     599.918       599       918
# 18526   2.049.946         0  11935397   2.049.946     2.049       946
# 13322   5.528.115         0  42931714   5.528.115     5.528       115
# 1058    1.599.862         0  5,49E+11   1.599.862     1.599       862
# 12882   7.131.788         0  12175397   7.879.496     7.879       496
# 15394       69.99         0  1,44E+11   6.999.003     6.999       003
# 14945     275.115         0      1298     349.932       349       932
# 15913  19.277.466         0  12175397  23.847.892    23.847       892
# 11204   7.371.792         0  12175397   7.480.582     7.480       582
# 14988     635.286         0      1298   6.352.863     6.352       863

# %%
three_decimals

# %%
two_decimals.sku.count()
# Out:
# 9434

# %%
price_ok.sku.count()
# Out:
# 9940

# %%
new = price_ok.copy()
new['price_float'] = pd.to_numeric(new['price'])

# %%
new.sample(5)
# Out:
#              sku                                               name  \
# 17953    GOP0098         Floaty GoPro Hero & Hero 5 Session Session
# 12344    SYN0141   Synology DS916 + | 2GB RAM Mac and PC Server Nas
# 19124  JBL0134-A                   Open - JBL T205 Black Headphones
# 8222     PAC1577  Apple iMac 21.5 "Core i7 3.3GHz 4K Retina | 8G...
# 18402    FIB0012   Fibaro HomeKit Wall Plug intelligent wall socket
#
#                                                     desc  price promo_price  \
# 17953  Specific float Session GoPro Hero to enjoy it ...  29.99     249.889
# 12344  4-bay NAS server and 2GB of RAM for Mac iPad a...  580.8   5.799.893
# 19124  JBL Reconditioned lightweight headphones so yo...  19.99      13.794
# 8222   Desktop computer iMac 21.5-inch 3.3GHz Core i7...   2449  19.565.944
# 18402  Plug smart power meter real-time compatible wi...  69.99     699.864
#
#        in_stock      type price_new price_num price_dec  price_float
# 17953         0      5403     29.99        29        99        29.99
# 12344         0  12175397     580.8       580         8       580.80
# 19124         0      5384     19.99        19        99        19.99
# 8222          0      1282   2449.00      2449        00      2449.00
# 18402         1  11905404     69.99        69        99        69.99

# %%
one_decimal.sku.count()
# Out:
# 506

# %% [markdown]
# ## Brands

# %% [markdown]
# The brands csv looks fine, so we can work together with it.

# %%
brands.to_csv(path + 'clean/brands.csv', index=False)
